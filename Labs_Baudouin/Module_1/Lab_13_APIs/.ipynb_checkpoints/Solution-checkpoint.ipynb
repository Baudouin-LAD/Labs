# %% [markdown]
# # API LAB

# %% [markdown]
# ### Challenge 1: Get a Picture
#   1. Go to the link https://xkcd.com
#   2. check the headers
#   3. check the  headers "Expires" value
#   4. Provide all HTML codes
#   5. Choose the random picture from the website
#   6. Get it via API
#   7. Save it to your computer

# %%
#1.
#2.
import requests
response = requests.get('https://xkcd.com')
headers = response.headers
#3
import requests
print('3.check the headers: ')
expires = headers['Expires']
print(f'Expires: {expires}')
#4
print('4.HTML codes:')
html_code = response.text
print(html_code)
#5
print('5. The image I chose can be found here: ',image)
image_url = 'https://imgs.xkcd.com/comics/slideshow.gif'
#6
print('6. here it is: ')
from IPython.core.display import Image as IPythonImage
response = requests.get('https://imgs.xkcd.com/comics/slideshow.gif')
image = IPythonImage(response.content)
display(image)
#7
img.save("/Users/Baudouin/Ironhack/Labs/Labs_Baudouin/Module_1/image.gif")
# Out:
# 3.check the headers:
# Expires: Wed, 25 Jan 2023 03:56:40 GMT
# 4.HTML codes:
# <!DOCTYPE html>
# <html>
# <head>
# <link rel="stylesheet" type="text/css" href="/s/7d94e0.css" title="Default"/>
# <title>xkcd: Lane Change Highway</title>
# <meta http-equiv="X-UA-Compatible" content="IE=edge"/>
# <link rel="shortcut icon" href="/s/919f27.ico" type="image/x-icon"/>
# <link rel="icon" href="/s/919f27.ico" type="image/x-icon"/>
# <link rel="alternate" type="application/atom+xml" title="Atom 1.0" href="/atom.xml"/>
# <link rel="alternate" type="application/rss+xml" title="RSS 2.0" href="/rss.xml"/>
# <!-- <script type="text/javascript" src="/s/b66ed7.js" async></script>
# <script type="text/javascript" src="/s/1b9456.js" async></script> -->
#
# <meta property="og:site_name" content="xkcd">
#
# <meta property="og:title" content="Lane Change Highway">
# <meta property="og:url" content="https://xkcd.com/2728/">
# ...

# %%
from IPython.display import Image
response = requests.get('https://xkcd.com/info.0.json').json()

# %%
Image(url=response["img"])
# Out:
# <img src="https://imgs.xkcd.com/comics/lane_change_highway.png"/>

# %% [markdown]
# ### Challenge 2: Get a password
# 1. Go to the https://httpbin.org/get. it is a simple HTTP libraries use for testing
# 2. View url
# 3. Add parameters to the request 'things':2,'total':25
# 4. Add username and password as parameters
# 5. Export username and password as dictionary

# %%
#1.
#2.
response = requests.get('https://httpbin.org/get')
#response.content
#3.
data = {'things':2,'total':25}
response2 = requests.get('https://httpbin.org/get', params=data)
print(response2.json())
#4.
data3 = {'username':'Baudouin','password':'Ironhack'}
response3 = requests.post('https://httpbin.org/post', data=data3)
print(response3.json())
#5
response4 = requests.get('https://httpbin.org/get',params = {'form'})
response4
# Out:
# {'args': {'things': '2', 'total': '25'}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate, br', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.28.1', 'X-Amzn-Trace-Id': 'Root=1-63d141e7-3b72a65c4b3234454159d39a'}, 'origin': '185.146.221.98', 'url': 'https://httpbin.org/get?things=2&total=25'}
# {'args': {}, 'data': '', 'files': {}, 'form': {'password': 'Ironhack', 'username': 'Baudouin'}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate, br', 'Content-Length': '35', 'Content-Type': 'application/x-www-form-urlencoded', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.28.1', 'X-Amzn-Trace-Id': 'Root=1-63d141e7-7de23ceb4f89248a2fb627e1'}, 'json': None, 'origin': '185.146.221.98', 'url': 'https://httpbin.org/post'}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ...
