# %%
import pandas as pd
import datetime as dt
import pandas_datareader.data as web

# %%
start_time = dt.datetime(2000, 1, 1)
end_time = dt.datetime(2022, 2, 1)
df = web.DataReader('idd', 'oecd', '2012-01-01', '2019-01-01')

# %%
data = pd.DataFrame(df.stack())
df.info()
df.head()
data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8 entries, 2012-01-01 to 2019-01-01
# Columns: 51480 entries, ('Australia', 'Gini (disposable income, post taxes and transfers)', 'Total population', 'Current definition', 'New income definition since 2012') to ('Romania', 'Consumer Price Index (base 2015=100)', 'Retirement age population: above 65', 'Previous definition - without overlap year', 'Income definition until 2011')
# dtypes: float64(51480)
# memory usage: 3.1 MB
# Country                                                                                  Australia  \
# Measure                                     Age group 0-17: Poverty rate after taxes and transfers
# Age group                                                      Retirement age population: above 65
# Definition                                                                      Current definition
# Year       Methodology
# ...

# %%
data.to_csv('/Users/Baudouin/Ironhack/Labs/Labs_Baudouin/Module_1/oecd.csv', index=False)
