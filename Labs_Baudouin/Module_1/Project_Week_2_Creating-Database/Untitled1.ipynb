# %%
import requests
import json
import pandas as pd
from pprint import pprint
from pandasdmx import Request
import lxml

# %%
# !pip install pandas

# %%
response = requests.get('http://stats.oecd.org/restsdmx/sdmx.ashx/GetDataStructure/IDD')
pprint(response.text)
# Out:
# ('<message:Structure '
#  'xmlns="http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure" '
#  'xmlns:common="http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common" '
#  'xsi:schemaLocation="http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure '
#  'http://www.sdmx.org/docs/2_0/SDMXStructure.xsd '
#  'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message '
#  'http://www.sdmx.org/docs/2_0/SDMXMessage.xsd" '
#  'xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" '
#  'xmlns:message="http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message"><Header '
#  'xmlns="http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message"><ID>none<!--Copyright '
#  'OECD - All rights reserved\n'
#  'Terms and Conditions\n'
#  'http://www.oecd.org/termsandconditions/\n'
#  'Privacy Policy\n'
#  'http://www.oecd.org/privacy/\n'
#  'MyOECD\n'
#  'https://www.oecd.org/login\n'
#  'Contact Us\n'
#  'http://www.oecd.org/contact/\n'
# ...

# %%
from lxml import etree

response = requests.get('http://stats.oecd.org/restsdmx/sdmx.ashx/GetDataStructure/IDD')
root = etree.fromstring(response.content)

header_id = root.xpath('//Header/ID')[0].text
print(header_id)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/3m/1c5hlk4x4qq78rxn2d26fd6w0000gn/T/ipykernel_12094/3063655318.py in <module>
#       4 root = etree.fromstring(response.content)
#       5
# ----> 6 header_id = root.xpath('//Header/ID')[0].text
#       7 print(header_id)
#
# IndexError: list index out of range

# %%
response = requests.get('https://stats.oecd.org/restsdmx/sdmx.ashx/GetData/IDD/DNK+FRA+DEU+GRC+HUN+ITA+PRT+ESP+GBR+USA.....TOT+WA+OLD.CURRENT.METH2012/all?startTime=2012&endTime=2019')
print(response.text)
# Out:
# ï»¿<message:MessageGroup xmlns="http://www.SDMX.org/resources/SDMXML/schemas/v2_0/generic" xmlns:common="http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common" xsi:schemaLocation="http://www.SDMX.org/resources/SDMXML/schemas/v2_0/generic http://www.sdmx.org/docs/2_0/SDMXGenericData.xsd http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message http://www.sdmx.org/docs/2_0/SDMXMessage.xsd" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:message="http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message"><Header xmlns="http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message"><ID>none</ID><Test>false</Test><Truncated>false</Truncated><Prepared>2023-01-29T16:05:32</Prepared><Sender id="OECD"><Name xml:lang="en">Organisation for Economic Co-operation and Development</Name><Name xml:lang="fr">Organisation de coopÃ©ration et de dÃ©veloppement Ã©conomiques</Name></Sender></Header><DataSet keyFamilyURI="https://stats-1.oecd.org/RestSDMX/sdmx.ashx/GetKeyFamily/IDD"><KeyFamilyRe
# ...

# %%
import sdmx
sdmx.to_pandas(response)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/3m/1c5hlk4x4qq78rxn2d26fd6w0000gn/T/ipykernel_12094/1486969587.py in <module>
#       1 import sdmx
# ----> 2 sdmx.to_pandas(response)
#
# AttributeError: module 'sdmx' has no attribute 'to_pandas'
